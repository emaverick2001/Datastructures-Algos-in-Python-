# %% [markdown]
# # PyTorch

# %% [markdown]
# - free and open source framework used for machine leanring research and application. It specializes in tensor computations, automatic differentiation, and GPU acceleration.

# %% [markdown]
# # PyTorch Geometric

# %% [markdown]
# # Captum

# %% [markdown]
# # skorch
