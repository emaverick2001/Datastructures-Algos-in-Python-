# %% [markdown]
# # Time Complexity

# %% [markdown]
# ## Rates of Growth

# %% [markdown]
# ## Types of Analysis

# %% [markdown]
# ### Worst Case

# %% [markdown]
# ### Best case

# %% [markdown]
# ### Average Case

# %% [markdown]
# ## Big-O-notation

# %% [markdown]
# ## Omega-Ω-notation

# %% [markdown]
# ## Theta-Θ-notation

# %% [markdown]
# ## Master theorem

# %% [markdown]
# ## Amortized Analysis

# %% [markdown]
# # Space Complexity
