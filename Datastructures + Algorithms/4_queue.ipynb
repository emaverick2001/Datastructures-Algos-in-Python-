# %% [markdown]
# # Implementations

# %% [markdown]
# # Methods / Operations

# %% [markdown]
# ## Creation

# %% [markdown]
# ## Access

# %% [markdown]
# # Corner Cases TODO add examples for each case

# %% [markdown]
# # Techniques

# %% [markdown]
# # Practice
