# %% [markdown]
# # Implementations

# %% [markdown]
# # Methods / Operations

# %% [markdown]
# # Corner Cases TODO add examples for each case

# %% [markdown]
# # Techniques

# %% [markdown]
# # Practice Projects
